# %% [markdown]
# # OpenStreet of Map Melbourne, AUS Case Study¶

# %% [markdown]
# This data set is downloaded from a ready extract of more than 200 areas world wide on BBBBike.
#     - https://download.bbbike.org/osm/

# %% [markdown]
# ### Understanding the map XML file and parrsing it using xml library in Python

# %% [markdown]
# #1
# Use the iterative parsing to process the map file and find out what tags are there, to get the feeling on how much of which data expected to have in the map.

# %%
import xml.etree.cElementTree as ET
import pprint
from collections import defaultdict

"""
Create a function called count_tags which iterate through the xml file looking for tags
and count those tags.
"""
def count_tags(filename):
    tags = defaultdict(int)
    tree = ET.parse('Melbourne.osm')
    root = tree.getroot()
    for element in root.iter():
        tags[element.tag] +=1
    return tags

def test():
    tags = count_tags('Melbourne.osm')
    pprint.pprint(tags)

if __name__ == "__main__":
    test()
# Out:
# defaultdict(<class 'int'>,
#             {'bounds': 1,
#              'member': 116983,
#              'nd': 2708537,
#              'node': 2301716,
#              'osm': 1,
#              'relation': 11990,
#              'tag': 2313691,
#              'way': 356310})

# %% [markdown]
# #### The next is to explore the data a bit more. Before processing the data and add it into database, check the "k" value for each "<tag>" and see if there are any potential problems. I would like to change the data model and expand the "addr:street" type of keys to a dictionary like this:
# {"address": {"street": "Some value"}}
# So, I have to see if we have such tags, and if we have any tags with problematic characters.
#
# Counting of each of four tag categories in a dictionary:
#   "lower", for tags that contain only lowercase letters and are valid,
#   "lower_colon", for otherwise valid tags with a colon in their names,
#   "problemchars", for tags with problematic characters, and
#   "other", for other tags that do not fall into the other three categories.

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":   
        # for tag in element.iter():
        if lower.match(element.attrib['k']):
            keys['lower'] += 1
        elif lower_colon.match(element.attrib['k']):
            keys['lower_colon'] += 1
        elif problemchars.match(element.attrib['k']):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

def test():
    keys = process_map('Melbourne.osm')
    pprint.pprint(keys)

if __name__ == "__main__":
    test()
# Out:
# {'lower': 1635015, 'lower_colon': 676293, 'other': 2383, 'problemchars': 0}

# %% [markdown]
# ### Auditing the street name

# %% [markdown]
# The list of street names are listed in 'expected', 'audit_street_type'would list all the street names if not included.

# %%
osmfile = "Melbourne.osm"

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
stret_types = defaultdict(set)


#expected street types
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Circle", "Crescent", "Gate", "Terrace", "Grove", "Way"]

#
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
   
#
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


#
def audit_street(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

audit_street_results = audit_street('Melbourne.osm')

def test():
    pprint.pprint(audit_street_results)

if __name__ == "__main__":
    test()
# Out:
# defaultdict(<class 'set'>,
#             {'251': {'251'},
#              'Airport': {'Arrival Drive Melbourne Airport'},
#              'Alley': {'Tin Alley', 'Croft Alley', 'Globe Alley'},
#              'Allister': {'Allister'},
#              'Arcade': {'Campbell Arcade',
#                         'Kings Arcade',
#                         'Preston Chambers Arcade'},
#              'Ave': {'Suite 1, St Vincent’s Private Hospital, 5 Studley Ave',
#                      'Victoria Ave'},
#              'Avp': {'Bayside Avp'},
#              'Balwyn': {'Balwyn'},
#              'Blvd': {'Quay Blvd'},
#              'Boardwalk': {'The Boardwalk'},
#              'Bouf': {'Logis Bouf'},
#              'Bourke': {'Little Bourke', 'Bourke'},
#              'Briars': {'The Briars'},
#              'Brighton': {'Brighton'},
#              'Broadway': {'Broadway'},
#              'Carlisle': {'Carlisle'},
#              'Carr': {'Carr'},
#              'Causeway': {'The Causeway'},
#              'Centerway': {'The Centerway', 'Centerway'},
#              'Centre)': {'Melbourne Central Shopping Centre Shop 146 Knox '
#                          'Lane, 211 La Trobe Street Melbourne, 3000 (Enter '
#                          'from Swanston or from inside the Centre)'},
#              'Centreway': {'Centreway', 'The Centreway'},
#              'Chase': {'Chevy Chase', 'Coolabindi Chase'},
#              'Church': {'Aspendale Presbyterian Church'},
#              'Circuit': {'Ashbrook Circuit',
#                          'Compark Circuit',
#                          'De Havilland Circuit',
#                          'Excelsior Circuit',
#                          'Glastonbury Circuit',
#                          'Hutchins Circuit',
#                          'Lansdowne Circuit',
#                          'Larkspur Circuit',
#                          'Livingstone Circuit',
#                          'Macquarie Circuit',
#                          'Metrolink Circuit',
#                          'Napoli Circuit',
#                          'Parkside Circuit',
#                          'Queensberry Circuit',
#                          'Richmond Circuit',
#                          'Sandon Circuit',
#                          'Simmington Circuit',
#                          'Stables Circuit',
#                          'Stadium Circuit',
#                          'Sun Orchid Circuit',
#                          'Technology Circuit',
#                          'The Circuit',
#                          'Tullimbar Circuit',
#                          'West Circuit'},
#              'Circus': {'Star Circus'},
#              'Close': {'Adele Close',
#                        'Affinity Close',
#                        'Aida Close',
#                        'Alto Close',
#                        'Alva Close',
#                        'Anderson Close',
#                        'Angela Close',
#                        'Anka Close',
#                        'Anthony Close',
#                        'Aplin Close',
#                        'Applegum Close',
#                        'Armour Close',
#                        'Ashley Close',
#                        'Ashton Close',
#                        'Ashwood Close',
#                        'Aspen Close',
#                        'Avonwood Close',
#                        'Ballard Close',
#                        'Bamber Close',
#                        'Banff Close',
#                        'Banjora Close',
#                        'Benjamin Close',
#                        'Besanko Close',
#                        'Billabong Close',
#                        'Billara Close',
#                        'Bindi Close',
#                        'Birkdale Close',
#                        'Blackfriars Close',
#                        'Blue Hills Close',
#                        'Bluegrass Close',
#                        'Border Close',
#                        'Box Close',
#                        'Boyle Close',
#                        'Brady Close',
#                        'Braimton Close',
#                        'Brampton Close',
#                        'Brentley Close',
#                        'Bromage Close',
#                        'Brothers Close',
#                        'Burraneer Close',
#                        'Capella Close',
#                        'Carina Close',
#                        'Carlisle Close',
#                        'Castle Close',
#                        'Ceduna Close',
#                        'Charles Wilson Close',
#                        'Chatswood Close',
#                        'Chequers Close',
#                        'Chester Close',
#                        'Christina Close',
#                        'Clifford Close',
#                        'Cliveden Close',
#                        'Collared Close',
#                        'Collendina Close',
#                        'Colonial Close',
#                        'Colston Close',
#                        'Coniston Close',
#                        'Coolomon Close',
#                        'Corker Close',
#                        'Correa Close',
#                        'County Close',
#                        'Crabapple Close',
#                        'Dalkeith Close',
#                        'Danielle Close',
#                        'Daphne Close',
#                        'Darvell Close',
#                        'David Close',
#                        'Davies Close',
#                        'Deanside Close',
#                        'Deanswood Close',
#                        'Debbie Close',
#                        'Debson Close',
#                        'Denise Close',
#                        'Derry Close',
#                        'Dotterel Close',
#                        'Doubell Close',
#                        'Downshire Close',
#                        'Drewe Close',
#                        'Dunbar Close',
#                        'Dunrossil Close',
#                        'Earle Close',
#                        'Edgeware Close',
#                        'Eliza Close',
#                        'Elle Close',
#                        'Elliot Close',
#                        'Ensign Close',
#                        'Eriden Close',
#                        'Exchange Close',
#                        'Finton Close',
#                        'Forbes Close',
#                        'Formby Close',
#                        'Gala Supreme Close',
#                        'Galtymore Close',
#                        'Gatwick Close',
#                        'Geordy Close',
#                        'Ghiran Close',
#                        'Gladesville Close',
#                        'Glen Innes Close',
#                        'Glen Orchard Close',
#                        'Glenn Innes Close',
#                        'Goodwood Close',
#                        'Gould Close',
#                        'Grant Close',
#                        'Greenmount Close',
#                        'Grevillea Close',
#                        'Gum Ridge Close',
#                        'Gum Tree Close',
#                        'Halidon Close',
#                        'Hanbury Close',
#                        'Hanlon Close',
#                        'Hartnett Close',
#                        'Harwick Close',
#                        'Harwood Close',
#                        'Hedgeley Close',
#                        'Hillgrove Close',
#                        'Hilson Close',
#                        'Homewood Close',
#                        'Hopman Close',
#                        'Hoysted Close',
#                        'Huron Close',
#                        'Hutchins Close',
#                        'Iolanthe Close',
#                        'Ironbark Close',
#                        'Janos Close',
#                        'Jenna Close',
#                        'Jessica Close',
#                        'Jodie Close',
#                        'Jonathan Close',
#                        'Jordan Close',
#                        'Judi Close',
#                        'Julie Close',
#                        'June Close',
#                        'Kara Close',
#                        'Karabil Close',
#                        'Keats Close',
#                        'Kemerton Close',
#                        'Kendall Close',
#                        'Kenman Close',
#                        'Kevlar Close',
#                        'Kiama Close',
#                        'Kianda Close',
#                        'Kiandra Close',
#                        'Kim Close',
#                        'Kimber Close',
#                        'Kimberley Close',
#                        'King Sound Close',
#                        'Kingsley Close',
#                        'Kingston Town Close',
#                        'Kinka Close',
#                        'Kinloch Close',
#                        'Kintbury Close',
#                        'Kirrum Close',
#                        'Kristen Close',
#                        'Kyreli Close',
#                        'Lancelot Close',
#                        'Leo Close',
#                        'Leyte Close',
#                        'Liam Close',
#                        'Lillee Close',
#                        'Lillian Close',
#                        'Lisa Close',
#                        'Longbeach Close',
#                        'Lovitt Close',
#                        'Lubbrook Close',
#                        'Manning Close',
#                        'Manor Close',
#                        'Mara Close',
#                        'Margaret Gray Close',
#                        'Maringa Close',
#                        'Mather Close',
#                        'Mawson Close',
#                        'Melanie Close',
#                        'Miga Close',
#                        'Milbrey Close',
#                        'Milner Close',
#                        'Miriam Close',
#                        'Mississippi Close',
#                        'Mita Close',
#                        'Mitta Close',
#                        'Moloney Close',
#                        'Monaro Close',
#                        'Monastery Close',
#                        'Montrose Close',
#                        'Moonrise Close',
#                        'Morgan Close',
#                        'Mosman Close',
#                        'Mura Close',
#                        'Murrindal Close',
#                        'Myra Close',
#                        'Nankin Close',
#                        'Napier Close',
#                        'Napoli Close',
#                        'Natasha Close',
#                        'Neston Close',
#                        'Nevada Close',
#                        'Newry Close',
#                        'Nicholson Close',
#                        'Nicole Close',
#                        "O'Brien Close",
#                        'Oakton Close',
#                        'Oonah Close',
#                        'Oregan Close',
#                        'Orlando Close',
#                        'Ormiston Close',
#                        'Orsova Close',
#                        'Ovata Close',
#                        'Oxley Close',
#                        'Pacific Close',
#                        'Panorama Close',
#                        'Parklands Close',
#                        'Parkway Close',
#                        'Pater Close',
#                        'Paulette Close',
#                        'Perry Close',
#                        'Pertaka Close',
#                        'Picolo Close',
#                        'Pineview Close',
#                        'Pintail Close',
#                        'Pioneer Close',
#                        'Player Close',
#                        'Primrose Hill Close',
#                        'Priscilla Close',
#                        'Purtell Close',
#                        'Putney Close',
#                        'Rainham Close',
#                        'Rebecca Close',
#                        'Reys Close',
#                        'Rimu Close',
#                        'Risdale Close',
#                        'Robin Close',
#                        'Rockley Close',
#                        'Rodney Close',
#                        'Rotherwood Close',
#                        'Roxby Close',
#                        'Roycroft Close',
#                        'Sally Close',
#                        'Samantha Close',
#                        'Samuel Close',
#                        'Scammell Close',
#                        'Scone Close',
#                        'Sean Close',
#                        'Selborne Close',
#                        'Sewart Close',
#                        'Seymour Close',
#                        'Shallot Close',
#                        'Silverbirch Close',
#                        'Silverton Close',
#                        'Simla Close',
#                        'Sion Close',
#                        'Solferino Close',
#                        'Solway Close',
#                        'Somali Close',
#                        'Southdowne Close',
#                        'Southwood Close',
#                        'Springwood Close',
#                        'St Margarets Close',
#                        'Standring Close',
#                        'Strand Close',
#                        'Strathaird Close',
#                        'Summerhill Close',
#                        'Sun Dew Close',
#                        'Sunmore Close',
#                        'Sunset Close',
#                        'Susan Close',
#                        'Tallis Close',
#                        'Talma Close',
#                        'Talwood Close',
#                        'Tandragee Close',
#                        'Tanunda Close',
#                        'Tara Close',
#                        'Tasman Close',
#                        'Tatyoon Close',
#                        'Teague Close',
#                        'Terrigal Close',
#                        'The Close',
#                        'Towyn Close',
#                        'Tracey Close',
#                        'Traydal Close',
#                        'Trevinden Close',
#                        'Triumph Close',
#                        'Tunbury Close',
#                        'Tyalla Close',
#                        'Tyne Close',
#                        'Ulah Close',
#                        'Ungara Close',
#                        'Ursula Close',
#                        'Utrillo Close',
#                        'Waiora Close',
#                        'Warrington Close',
#                        'Warwick Close',
#                        'Wembley Close',
#                        'Wendy Close',
#                        'Williamson Close',
#                        'Wingate Close',
#                        'Wydell Close',
#                        'Yandell Close',
#                        'Yarra Hill Close'},
#              'Concord': {'The Concord'},
#              'Concourse': {'East Concourse',
#                            'Merri Concourse',
#                            'North Concourse'},
#              'Corso': {'The Corso'},
#              'Cres': {'Strome Cres'},
#              'Cresent': {'Alchester Cresent'},
#              'Crest': {'Falcon Crest', 'The Crest'},
#              'Croft': {'The Croft'},
#              'Crossway': {'The Crossway'},
#              'Dalbeattie': {'Dalbeattie'},
#              'Deviation': {'The Deviation'},
#              'Dr,': {'London Dr,', 'Indian Dr,'},
#              'Dr.': {'London Dr.'},
#              'East': {'Argyle Place East',
#                       'Barmah Drive East',
#                       'Bayfield Road East',
#                       'Belmont Road East',
#                       'Blackburn Road East',
#                       'Bungalook Road East',
#                       'Como Parade East',
#                       'Foster Street East',
#                       'Grant Street East',
#                       'Main Road East',
#                       'Railway Place East'},
#              'Edward.Street': {'Edward.Street'},
#              'Eileen': {'Eileen'},
#              'Elder': {'Elder'},
#              'Elizabeth': {'Elizabeth'},
#              'Elms': {'The Elms'},
#              'Esplanade': {'East Esplanade',
#                            'Esplanade',
#                            'Harbour Esplanade',
#                            'Lower Esplanade',
#                            'Ormond Esplanade',
#                            'The Esplanade'},
#              'Eyrie': {'The Eyrie'},
#              'Fairway': {'The Fairway'},
#              'Ferrars': {'Ferrars'},
#              'Footbridge': {'Bourke Street Footbridge'},
#              'Ford': {'Glenara Ford'},
#              'Franklyn': {'Franklyn'},
#              'Gardens': {'Covent Gardens',
#                          'Georgian Gardens',
#                          'Harrow Gardens',
#                          'Kingfisher Gardens',
#                          'Tivoli Gardens',
#                          'Wembley Gardens',
#                          'Wroxham Gardens'},
#              'Gateway': {'Nerreman Gateway', 'The Gateway'},
#              'George': {'George'},
#              'Georgette': {'Georgette'},
#              'Glade': {'The Glade', 'Bushview Glade'},
#              'Glen': {'Dawsons Glen', 'Keswick Glen'},
#              'Glenhuntly': {'Glenhuntly'},
#              'Gr': {'McCarthy Gr'},
#              'Grange': {'The Grange'},
#              'Green': {'Dublin Green'},
#              'Greensborough': {'253 Para Road, Greensborough'},
#              'Havilland': {'De Havilland'},
#              'Heath': {'Aston Heath', 'The Heath'},
#              'Heatherton': {'Heatherton'},
#              'Highway': {'Burwood Highway',
#                          'Hume Highway',
#                          'Maroondah Highway',
#                          'Melton Highway',
#                          'Mountain Highway',
#                          'Neapean Highway',
#                          'Nepean Highway',
#                          'Old Calder Highway',
#                          'Princes Highway',
#                          'Princess Highway',
#                          'South Gippsland Highway',
#                          'The Highway'},
#              'Higl': {'Princes Higl'},
#              'Higway': {'Maroondah Higway'},
#              'Hill': {'Artists Hill',
#                       'Forrest Hill',
#                       'Graduate Road, University Hill'},
#              'House': {'Thomas House'},
#              'Hub': {'Community Hub'},
#              'Illawara': {'Illawara'},
#              'Kidderminster': {'Kidderminster'},
#              'Kingsway': {'Kingsway'},
#              'Knoll': {'The Knoll'},
#              'Lane.': {'Guildford Lane.'},
#              'Langhorne': {'Langhorne'},
#              'Langridge': {'Langridge'},
#              'Link': {'Woody Link'},
#              'Lonsdale': {'Lt Lonsdale'},
#              'Mall': {'Bourke Street Mall',
#                       'Brittania Mall',
#                       'Dennison Mall',
#                       'Eaton Mall',
#                       'Nicholson Street Mall',
#                       'The Mall'},
#              'Malvern': {'Malvern'},
#              'Marden': {'Marden'},
#              'Maygar': {'Maygar'},
#              'Melbourne': {'Cardigan Street, Melbourne',
#                            'Cnr City Road & Cecil Street South Melbourne'},
#              'Mews': {'Abbey Mews',
#                       'Anley Mews',
#                       'Eucalyptus Mews',
#                       'Fisher Mews',
#                       'Gregory Mews',
#                       'McAllister Mews',
#                       'Montvale Mews',
#                       'Natalie Mews',
#                       'Punari Mews',
#                       'Selo Mews',
#                       'Steorra Mews',
#                       'The Mews'},
#              'Morton': {'Morton'},
#              'Nelson': {'Nelson'},
#              'Nook': {'The Nook'},
#              'North': {'Bannons Lane North',
#                        'Belmont Avenue North',
#                        'Brunswick Street North',
#                        'Harley Street North',
#                        'Laurel Grove North',
#                        'Lincoln Square North',
#                        'North',
#                        'Railway Parade North',
#                        'Yarra Road, Croydon North'},
#              'Offramp': {'Racecourse Road Offramp'},
#              'Orrong': {'Orrong'},
#              'Outlook': {'The Outlook'},
#              'Oxford': {'Oxford'},
#              'P': {'P'},
#              'Parade': {'Alexandra Parade',
#                         'Alexandria Parade',
#                         'Anderson Parade',
#                         'Auburn Parade',
#                         'Barkly Parade',
#                         'Beaconsfield Parade',
#                         'Beaumaris Parade',
#                         'Boldrewood Parade',
#                         'Bundora Parade',
#                         'Cameron Parade',
#                         'Campbell Parade',
#                         'Champion Parade',
#                         'Civic Parade',
#                         'Clough Parade',
#                         'Coleman Parade',
#                         'Creek Parade',
#                         'Cullis Parade',
#                         'Darlington Parade',
#                         'Doynton Parade',
#                         'Dudley Parade',
#                         'Dunstan Parade',
#                         'Eildon Parade',
#                         'Ellingworth Parade',
#                         'Fairhills Parade',
#                         'Fullwood Parade',
#                         'Gardiner Parade',
#                         'Garwain Parade',
#                         'George Parade',
#                         'Grammar Parade',
#                         'Grieve Parade',
#                         'Guinevere Parade',
#                         'Hillsyde Parade',
#                         'Holt Parade',
#                         'Hughes Parade',
#                         'Jenola Parade',
#                         'Jull Parade',
#                         'Kemilworth Parade',
#                         'Keon Parade',
#                         'Lawson Parade',
#                         'Liberty Parade',
#                         'Livingstone Parade',
#                         'Lynnwood Parade',
#                         'Macedon Parade',
#                         'Marine Parade',
#                         'Marriott Parade',
#                         'Mentone Parade',
#                         'Meridian Parade',
#                         'Milton Parade',
#                         'Montana Parade',
#                         'Mount View Parade',
#                         'Mountain View Parade',
#                         'Notre Dame Parade',
#                         'Pearcedale Parade',
#                         'Polo Parade',
#                         'Prosper Parade',
#                         'Queens Parade',
#                         'Railway Parade',
#                         'Robbs Parade',
#                         'Robern Parade',
#                         'Rostrevor Parade',
#                         'Rowena Parade',
#                         'Royal Parade',
#                         'Sea Parade',
#                         'Slater Parade',
#                         'South Parade',
#                         'Thaxted Parade',
#                         'The Parade',
#                         'Tom Roberts Parade',
#                         'Tunaley Parade',
#                         'Valley Parade',
#                         'Vermont Parade',
#                         'Victoria Parade',
#                         'Viggers Parade',
#                         'Webber Parade',
#                         'Welfare Parade',
#                         'Wellington Parade',
#                         'Wildwood Parade'},
#              'Park': {'Hyde Park', 'Friar Park', 'Batman Park'},
#              'Pier': {'West Finger Pier', 'Station Pier'},
#              'Pocket': {'Hazelview Pocket'},
#              'Preston': {'2B Stott St Preston'},
#              'Promenade': {'Newquay Promenade',
#                            'Saltwater Promenade',
#                            'South Wharf Promenade',
#                            'Southbank Promenade',
#                            'The Promenade',
#                            'Troups Creek Promenade',
#                            'Victoria Harbour Promenade'},
#              'Quadrangle': {'The Quadrangle'},
#              'Quadrant': {'Rathmullen Quadrant'},
#              'Quay': {'Riverside Quay'},
#              'Rd': {'Bayswater Rd',
#                     'Burke Rd',
#                     'Cochranes Rd',
#                     'Cotham Rd',
#                     'Doncaster Rd',
#                     'Greens Rd',
#                     'Reserve Rd',
#                     'Riversdale Rd',
#                     'Roberts Rd',
#                     'Sydney Rd',
#                     'Warrigal Rd'},
#              'Reserve': {'Burwood Highway, East Burwood Reserve'},
#              'Ridge': {'The Ridge', 'Monarch Ridge', 'Killarney Ridge'},
#              'Righi': {'The Righi'},
#              'Rise': {'Aqua Rise',
#                       'Cathedral Rise',
#                       'Chantelle Rise',
#                       'Fasan Rise',
#                       'Feathertop Rise',
#                       'Felicia Rise',
#                       'Fifer Rise',
#                       'Greenhill Rise',
#                       'Heathfield Rise',
#                       'Lestwick Rise',
#                       'Niland Rise',
#                       'Oaktree Rise',
#                       'Outlook Rise',
#                       'Richardson Rise',
#                       'Rosella Rise',
#                       'Rowena Rise',
#                       'Sanctuary Rise',
#                       'Scenic Rise',
#                       'Sherwood Rise',
#                       'Sovereign Rise',
#                       'Spring Rise',
#                       'St. Leger Rise',
#                       'Stanlake Rise',
#                       'Sun Rise',
#                       'Sunderland Rise',
#                       'Sunny Rise',
#                       'Talisman Rise',
#                       'The Rise',
#                       'Tintern Rise',
#                       'Toogoods Rise',
#                       'Troodos Rise',
#                       'Tuscany Rise',
#                       'Viewgrand Rise'},
#              'Ro': {'Scoresby Ro'},
#              'Road1': {'Dynon Road1'},
#              'Roads': {'Corner Plenty & Greenhills Roads',
#                        'Sydney and Brunswick Roads'},
#              'Roah': {'Camberwell Roah'},
#              'Roađ': {'Murray Roađ', 'Avalon Roađ'},
#              'Robbins': {'The Robbins'},
#              'Roberts': {'Tom Roberts'},
#              'Rof': {'Newlands Rof', 'Dunhelen Rof'},
#              'Rog': {'Dandenong - Frankston Rog'},
#              'Round': {'Lower Dandenong Round'},
#              'Rouse': {'Rouse'},
#              'Roy': {'Whitehorse Roy'},
#              'Run': {'The Old Stock Run'},
#              'STREET': {'PARK STREET'},
#              'Sands': {'The Sands'},
#              'Siddeley': {'Siddeley'},
#              'South': {'Ailsa Street South',
#                        'Albert Road Drive South',
#                        'Argyle Place South',
#                        'Ascot Street South',
#                        'Baird Street South',
#                        'Crellin Avenue South',
#                        'Gordon Avenue South',
#                        'High Street South',
#                        'Huntingdale Road South',
#                        'Lincoln Square South',
#                        'Oakdene Grove South',
#                        'Railway Street South',
#                        'St Georges Road South',
#                        'Strzelecki Grove South',
#                        'Sturt Street South'},
#              'Springfield': {'Springfield'},
#              'St': {'227 Collins St',
#                     'Adelaide St',
#                     'Bay St',
#                     'Collins St',
#                     'Elisabeth St',
#                     'Fehon St',
#                     'Greville St',
#                     'Lygon St',
#                     'Pelham St',
#                     'Susan St',
#                     'Swan St',
#                     'Swanston St',
#                     'Victoria St',
#                     'Whiteman St',
#                     'William St',
#                     'kennedy St'},
#              'St.': {'Separation St.'},
#              'Station': {'Second Hand Station', 'Station Station'},
#              'Stawell': {'Stawell'},
#              'Stc': {'Buckhurst Stc'},
#              'Stf': {'Station Stf'},
#              'Stg': {'Lacey Stg'},
#              'Strand': {'The Strand'},
#              'Street)': {'Primrose Street (cnr Albion Street)'},
#              'Street,': {'Graham Street,'},
#              'Street.': {'Amery Street.'},
#              'Streets': {'Bourke and Swanston Streets',
#                          'Corner Grey and Simpson Streets',
#                          'cnr Arden & Dryburgh Streets'},
#              'Summit': {'The Summit'},
#              'Swallow': {'Swallow'},
#              'Tho': {'Tho'},
#              'Toorak': {'Toorak'},
#              'Track': {'Loughies Track'},
#              'Trobe': {'La Trobe'},
#              'Turner': {'Turner'},
#              'VIC': {'high Street, Armadale VIC'},
#              'Vaucluse': {'The Vaucluse'},
#              'Victoria': {'Victoria'},
#              'View': {'Cascades View', 'Sky View', 'Kaleno View'},
#              'Village': {'Dingley Village'},
#              'W': {'Bond St W'},
#              'Walk': {'Abbey Walk',
#                       'Batman Walk',
#                       'Berrywood Walk',
#                       "Chancellor's Walk",
#                       'Cherry Walk',
#                       'College Walk',
#                       'Dukes Walk',
#                       'Eagleview Walk',
#                       'Flinders Walk',
#                       'Forest Walk',
#                       'Illowra Walk',
#                       'Innovation Walk',
#                       'Jacobus Walk',
#                       'Kara Walk',
#                       'Knoll Walk',
#                       'Lightwood Walk',
#                       'Maculata Walk',
#                       'Mulberry Walk',
#                       "Professor's Walk",
#                       'Railway Walk',
#                       'Rainforest Walk',
#                       'Rebecca Walk',
#                       'Saligna Walk',
#                       'Solstice Walk',
#                       'Sports Walk',
#                       'Waterview Walk',
#                       'Woodcock Walk'},
#              'Want': {'Centre Want'},
#              'West': {'Barmah Drive West',
#                       'Belmont Road West',
#                       'Bond Street West',
#                       'Como Parade West',
#                       'Craigieburn Road West',
#                       'Grant Crescent West',
#                       'Kirkham Road West',
#                       'Main Road West',
#                       'Manningham Road West',
#                       'Metrolink Circuit West',
#                       'Nell Street West',
#                       'Palmerston Road West',
#                       'Surrey Road West',
#                       'Toorak Road West'},
#              'Wharf': {'Federation Wharf'},
#              'Woodland': {'The Woodland'},
#              'Wynd': {'Yates Wynd', 'Buvelot Wynd'},
#              'call': {'Miller Street call'},
#              'd': {'Dandenong - Frankston Road d'},
#              'driveway': {'driveway'},
#              'rd': {'Murrayd rd'},
#              'road': {'Murray road',
#                       'Sydney road',
#                       'Waverley road',
#                       'Wheatherall road',
#                       'Whitehorse road'},
#              'street': {'Church street',
#                         'Grantham street',
#                         'Kavanagh street',
#                         'Moubray street',
#                         'black street',
#                         'collins street',
#                         'walter street'},
#              'tha': {'tha'}})

# %% [markdown]
# It can be found that there are many discrepancies in the street names such as:
#
#             "St.": "Street",
#             "St":"Street",
#             "Dr.": "Drive",
#             "Dr,": "Drive",
#             "Rd": "Road",
#             "Ro": "Road",
#             "rd":"Road",

# %% [markdown]
# ### Correcting the street names

# %% [markdown]
# The function update_name will update the upon wrong names to correct ones.

# %%
osmfile = "Melbourne.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

mapping = { 
            "St.": "Street",
            "St":"Street",
            "Dr.": "Drive",
            "Dr,": "Drive",
            "Rd": "Road",
            "Ro": "Road",
            "rd":"Road",
            }

def update_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

    return name

for street_type, ways in audit_street_results.items():
    for name in ways:
        better_name = update_name(name, mapping, street_type_re)
        print (name, "=>", better_name)
# Out:
# Eildon Parade => Eildon Parade
# Ellingworth Parade => Ellingworth Parade
# Campbell Parade => Campbell Parade
# Thaxted Parade => Thaxted Parade
# Marine Parade => Marine Parade
# Rowena Parade => Rowena Parade
# Robbs Parade => Robbs Parade
# Livingstone Parade => Livingstone Parade
# Lawson Parade => Lawson Parade
# Beaconsfield Parade => Beaconsfield Parade
# Gardiner Parade => Gardiner Parade
# Bundora Parade => Bundora Parade
# Rostrevor Parade => Rostrevor Parade
# Robern Parade => Robern Parade
# Montana Parade => Montana Parade
# Alexandra Parade => Alexandra Parade
# Cameron Parade => Cameron Parade
# Auburn Parade => Auburn Parade
# Kemilworth Parade => Kemilworth Parade
# Wildwood Parade => Wildwood Parade
# Civic Parade => Civic Parade
# Champion Parade => Champion Parade
# Prosper Parade => Prosper Parade
# Alexandria Parade => Alexandria Parade
# Cullis Parade => Cullis Parade
# South Parade => South Parade
# Polo Parade => Polo Parade
# Queens Parade => Queens Parade
# Anderson Parade => Anderson Parade
# Viggers Parade => Viggers Parade
# Fairhills Parade => Fairhills Parade
# Mentone Parade => Mentone Parade
# Grammar Parade => Grammar Parade
# Coleman Parade => Coleman Parade
# Welfare Parade => Welfare Parade
# Grieve Parade => Grieve Parade
# Mount View Parade => Mount View Parade
# George Parade => George Parade
# Liberty Parade => Liberty Parade
# Garwain Parade => Garwain Parade
# Vermont Parade => Vermont Parade
# Keon Parade => Keon Parade
# Marriott Parade => Marriott Parade
# Hillsyde Parade => Hillsyde Parade
# Hughes Parade => Hughes Parade
# Dudley Parade => Dudley Parade
# Doynton Parade => Doynton Parade
# Jenola Parade => Jenola Parade
# Pearcedale Parade => Pearcedale Parade
# Jull Parade => Jull Parade
# Fullwood Parade => Fullwood Parade
# Sea Parade => Sea Parade
# Slater Parade => Slater Parade
# Clough Parade => Clough Parade
# Darlington Parade => Darlington Parade
# Valley Parade => Valley Parade
# Beaumaris Parade => Beaumaris Parade
# Lynnwood Parade => Lynnwood Parade
# Mountain View Parade => Mountain View Parade
# Webber Parade => Webber Parade
# Guinevere Parade => Guinevere Parade
# Railway Parade => Railway Parade
# Barkly Parade => Barkly Parade
# Notre Dame Parade => Notre Dame Parade
# The Parade => The Parade
# Milton Parade => Milton Parade
# Royal Parade => Royal Parade
# Tom Roberts Parade => Tom Roberts Parade
# Meridian Parade => Meridian Parade
# Victoria Parade => Victoria Parade
# Boldrewood Parade => Boldrewood Parade
# Holt Parade => Holt Parade
# Creek Parade => Creek Parade
# Tunaley Parade => Tunaley Parade
# Macedon Parade => Macedon Parade
# Wellington Parade => Wellington Parade
# Dunstan Parade => Dunstan Parade
# Sturt Street South => Sturt Street South
# Argyle Place South => Argyle Place South
# Albert Road Drive South => Albert Road Drive South
# High Street South => High Street South
# Gordon Avenue South => Gordon Avenue South
# Strzelecki Grove South => Strzelecki Grove South
# Ailsa Street South => Ailsa Street South
# Oakdene Grove South => Oakdene Grove South
# Ascot Street South => Ascot Street South
# Huntingdale Road South => Huntingdale Road South
# St Georges Road South => St Georges Road South
# Lincoln Square South => Lincoln Square South
# Baird Street South => Baird Street South
# Railway Street South => Railway Street South
# Crellin Avenue South => Crellin Avenue South
# Neapean Highway => Neapean Highway
# South Gippsland Highway => South Gippsland Highway
# Hume Highway => Hume Highway
# Burwood Highway => Burwood Highway
# Nepean Highway => Nepean Highway
# Princess Highway => Princess Highway
# Maroondah Highway => Maroondah Highway
# Melton Highway => Melton Highway
# The Highway => The Highway
# Mountain Highway => Mountain Highway
# Princes Highway => Princes Highway
# Old Calder Highway => Old Calder Highway
# The Esplanade => The Esplanade
# Lower Esplanade => Lower Esplanade
# Esplanade => Esplanade
# Ormond Esplanade => Ormond Esplanade
# East Esplanade => East Esplanade
# Harbour Esplanade => Harbour Esplanade
# Melanie Close => Melanie Close
# Downshire Close => Downshire Close
# Billara Close => Billara Close
# Murrindal Close => Murrindal Close
# Gladesville Close => Gladesville Close
# Manning Close => Manning Close
# Lovitt Close => Lovitt Close
# Kinka Close => Kinka Close
# Ballard Close => Ballard Close
# Colston Close => Colston Close
# Harwood Close => Harwood Close
# Mura Close => Mura Close
# Kemerton Close => Kemerton Close
# Eliza Close => Eliza Close
# Burraneer Close => Burraneer Close
# Roxby Close => Roxby Close
# Wendy Close => Wendy Close
# Ulah Close => Ulah Close
# June Close => June Close
# Armour Close => Armour Close
# Triumph Close => Triumph Close
# Samuel Close => Samuel Close
# Mississippi Close => Mississippi Close
# Alva Close => Alva Close
# Player Close => Player Close
# Rebecca Close => Rebecca Close
# Sion Close => Sion Close
# St Margarets Close => St Margarets Close
# Sean Close => Sean Close
# Galtymore Close => Galtymore Close
# Keats Close => Keats Close
# Rainham Close => Rainham Close
# Drewe Close => Drewe Close
# Mawson Close => Mawson Close
# Kimber Close => Kimber Close
# Anka Close => Anka Close
# David Close => David Close
# Elle Close => Elle Close
# Tasman Close => Tasman Close
# Ursula Close => Ursula Close
# Brentley Close => Brentley Close
# Forbes Close => Forbes Close
# Iolanthe Close => Iolanthe Close
# Scammell Close => Scammell Close
# Roycroft Close => Roycroft Close
# Neston Close => Neston Close
# Warwick Close => Warwick Close
# Lillee Close => Lillee Close
# Southdowne Close => Southdowne Close
# Pacific Close => Pacific Close
# Hoysted Close => Hoysted Close
# Pater Close => Pater Close
# Napoli Close => Napoli Close
# Waiora Close => Waiora Close
# Longbeach Close => Longbeach Close
# Dunrossil Close => Dunrossil Close
# Jenna Close => Jenna Close
# Pertaka Close => Pertaka Close
# Solferino Close => Solferino Close
# Blue Hills Close => Blue Hills Close
# Kingston Town Close => Kingston Town Close
# Darvell Close => Darvell Close
# Yarra Hill Close => Yarra Hill Close
# Debbie Close => Debbie Close
# Hartnett Close => Hartnett Close
# Hanlon Close => Hanlon Close
# Bluegrass Close => Bluegrass Close
# Parklands Close => Parklands Close
# Wembley Close => Wembley Close
# Milner Close => Milner Close
# Tracey Close => Tracey Close
# Huron Close => Huron Close
# Panorama Close => Panorama Close
# Glenn Innes Close => Glenn Innes Close
# Gatwick Close => Gatwick Close
# Deanside Close => Deanside Close
# Box Close => Box Close
# Monaro Close => Monaro Close
# Natasha Close => Natasha Close
# Springwood Close => Springwood Close
# Rotherwood Close => Rotherwood Close
# Towyn Close => Towyn Close
# Napier Close => Napier Close
# Tunbury Close => Tunbury Close
# Pioneer Close => Pioneer Close
# Simla Close => Simla Close
# Brothers Close => Brothers Close
# Wingate Close => Wingate Close
# Nevada Close => Nevada Close
# Aspen Close => Aspen Close
# Strand Close => Strand Close
# Bromage Close => Bromage Close
# Alto Close => Alto Close
# Geordy Close => Geordy Close
# Kim Close => Kim Close
# Nankin Close => Nankin Close
# Nicole Close => Nicole Close
# Tatyoon Close => Tatyoon Close
# Gala Supreme Close => Gala Supreme Close
# Myra Close => Myra Close
# Banff Close => Banff Close
# Davies Close => Davies Close
# Gum Ridge Close => Gum Ridge Close
# Janos Close => Janos Close
# Gould Close => Gould Close
# Lisa Close => Lisa Close
# Hopman Close => Hopman Close
# Oxley Close => Oxley Close
# Rodney Close => Rodney Close
# Chequers Close => Chequers Close
# Hanbury Close => Hanbury Close
# The Close => The Close
# Selborne Close => Selborne Close
# Ovata Close => Ovata Close
# Perry Close => Perry Close
# Purtell Close => Purtell Close
# Chatswood Close => Chatswood Close
# Orsova Close => Orsova Close
# Parkway Close => Parkway Close
# Anthony Close => Anthony Close
# Harwick Close => Harwick Close
# Solway Close => Solway Close
# Applegum Close => Applegum Close
# Anderson Close => Anderson Close
# Ashwood Close => Ashwood Close
# Deanswood Close => Deanswood Close
# Williamson Close => Williamson Close
# Monastery Close => Monastery Close
# Teague Close => Teague Close
# Bindi Close => Bindi Close
# Hutchins Close => Hutchins Close
# Kianda Close => Kianda Close
# Daphne Close => Daphne Close
# Picolo Close => Picolo Close
# Scone Close => Scone Close
# Kintbury Close => Kintbury Close
# Collendina Close => Collendina Close
# Pineview Close => Pineview Close
# Seymour Close => Seymour Close
# Moloney Close => Moloney Close
# Ashley Close => Ashley Close
# Kevlar Close => Kevlar Close
# Sunset Close => Sunset Close
# Billabong Close => Billabong Close
# Coolomon Close => Coolomon Close
# Dalkeith Close => Dalkeith Close
# Hilson Close => Hilson Close
# Tara Close => Tara Close
# Elliot Close => Elliot Close
# Rockley Close => Rockley Close
# Braimton Close => Braimton Close
# Priscilla Close => Priscilla Close
# Jodie Close => Jodie Close
# Miriam Close => Miriam Close
# Ashton Close => Ashton Close
# Exchange Close => Exchange Close
# Aplin Close => Aplin Close
# Cliveden Close => Cliveden Close
# Summerhill Close => Summerhill Close
# Risdale Close => Risdale Close
# Adele Close => Adele Close
# Silverbirch Close => Silverbirch Close
# Sunmore Close => Sunmore Close
# Debson Close => Debson Close
# Mara Close => Mara Close
# Tanunda Close => Tanunda Close
# Somali Close => Somali Close
# Charles Wilson Close => Charles Wilson Close
# Kimberley Close => Kimberley Close
# County Close => County Close
# Corker Close => Corker Close
# Ceduna Close => Ceduna Close
# Shallot Close => Shallot Close
# Carlisle Close => Carlisle Close
# Christina Close => Christina Close
# Formby Close => Formby Close
# Ensign Close => Ensign Close
# Oregan Close => Oregan Close
# Goodwood Close => Goodwood Close
# Earle Close => Earle Close
# Brampton Close => Brampton Close
# Pintail Close => Pintail Close
# Aida Close => Aida Close
# Samantha Close => Samantha Close
# Liam Close => Liam Close
# Grevillea Close => Grevillea Close
# Kenman Close => Kenman Close
# Terrigal Close => Terrigal Close
# Lancelot Close => Lancelot Close
# Chester Close => Chester Close
# Blackfriars Close => Blackfriars Close
# Hillgrove Close => Hillgrove Close
# Mather Close => Mather Close
# Manor Close => Manor Close
# Paulette Close => Paulette Close
# Judi Close => Judi Close
# Mosman Close => Mosman Close
# Sun Dew Close => Sun Dew Close
# Talma Close => Talma Close
# Milbrey Close => Milbrey Close
# Talwood Close => Talwood Close
# Border Close => Border Close
# Dotterel Close => Dotterel Close
# Boyle Close => Boyle Close
# Clifford Close => Clifford Close
# Leyte Close => Leyte Close
# Kiama Close => Kiama Close
# Tallis Close => Tallis Close
# Standring Close => Standring Close
# Tyalla Close => Tyalla Close
# Doubell Close => Doubell Close
# Castle Close => Castle Close
# Kiandra Close => Kiandra Close
# Bamber Close => Bamber Close
# Reys Close => Reys Close
# Tyne Close => Tyne Close
# Jordan Close => Jordan Close
# Kyreli Close => Kyreli Close
# Julie Close => Julie Close
# Miga Close => Miga Close
# Ormiston Close => Ormiston Close
# Avonwood Close => Avonwood Close
# Affinity Close => Affinity Close
# Kristen Close => Kristen Close
# Utrillo Close => Utrillo Close
# Lillian Close => Lillian Close
# Halidon Close => Halidon Close
# Robin Close => Robin Close
# Maringa Close => Maringa Close
# Gum Tree Close => Gum Tree Close
# Trevinden Close => Trevinden Close
# Newry Close => Newry Close
# Birkdale Close => Birkdale Close
# Southwood Close => Southwood Close
# Tandragee Close => Tandragee Close
# Carina Close => Carina Close
# Putney Close => Putney Close
# Ghiran Close => Ghiran Close
# Dunbar Close => Dunbar Close
# Traydal Close => Traydal Close
# Banjora Close => Banjora Close
# Kirrum Close => Kirrum Close
# Edgeware Close => Edgeware Close
# Mita Close => Mita Close
# Danielle Close => Danielle Close
# Glen Orchard Close => Glen Orchard Close
# Nicholson Close => Nicholson Close
# Jessica Close => Jessica Close
# Collared Close => Collared Close
# Grant Close => Grant Close
# Greenmount Close => Greenmount Close
# Wydell Close => Wydell Close
# Ungara Close => Ungara Close
# Susan Close => Susan Close
# Sewart Close => Sewart Close
# Crabapple Close => Crabapple Close
# Brady Close => Brady Close
# Besanko Close => Besanko Close
# Karabil Close => Karabil Close
# Strathaird Close => Strathaird Close
# Leo Close => Leo Close
# Yandell Close => Yandell Close
# Moonrise Close => Moonrise Close
# Kingsley Close => Kingsley Close
# Finton Close => Finton Close
# Primrose Hill Close => Primrose Hill Close
# Morgan Close => Morgan Close
# Warrington Close => Warrington Close
# Margaret Gray Close => Margaret Gray Close
# Angela Close => Angela Close
# Oonah Close => Oonah Close
# Benjamin Close => Benjamin Close
# King Sound Close => King Sound Close
# Homewood Close => Homewood Close
# Kinloch Close => Kinloch Close
# Correa Close => Correa Close
# Denise Close => Denise Close
# Coniston Close => Coniston Close
# Jonathan Close => Jonathan Close
# Orlando Close => Orlando Close
# O'Brien Close => O'Brien Close
# Eriden Close => Eriden Close
# Kendall Close => Kendall Close
# Mitta Close => Mitta Close
# Hedgeley Close => Hedgeley Close
# Colonial Close => Colonial Close
# Oakton Close => Oakton Close
# Kara Close => Kara Close
# Sally Close => Sally Close
# Derry Close => Derry Close
# Rimu Close => Rimu Close
# Glen Innes Close => Glen Innes Close
# Ironbark Close => Ironbark Close
# Lubbrook Close => Lubbrook Close
# Montrose Close => Montrose Close
# Silverton Close => Silverton Close
# Capella Close => Capella Close
# Whitehorse road => Whitehorse road
# Murray road => Murray road
# Wheatherall road => Wheatherall road
# Waverley road => Waverley road
# Sydney road => Sydney road
# Dingley Village => Dingley Village
# Federation Wharf => Federation Wharf
# Riverside Quay => Riverside Quay
# Victoria St => Victoria Street
# Lygon St => Lygon Street
# 227 Collins St => 227 Collins Street
# Adelaide St => Adelaide Street
# William St => William Street
# Collins St => Collins Street
# Pelham St => Pelham Street
# kennedy St => kennedy Street
# Bay St => Bay Street
# Elisabeth St => Elisabeth Street
# Fehon St => Fehon Street
# Swan St => Swan Street
# Susan St => Susan Street
# Greville St => Greville Street
# Swanston St => Swanston Street
# Whiteman St => Whiteman Street
# Graham Street, => Graham Street,
# The Centerway => The Centerway
# Centerway => Centerway
# Sunderland Rise => Sunderland Rise
# Sovereign Rise => Sovereign Rise
# Feathertop Rise => Feathertop Rise
# Fifer Rise => Fifer Rise
# Troodos Rise => Troodos Rise
# St. Leger Rise => St. Leger Rise
# Sun Rise => Sun Rise
# Viewgrand Rise => Viewgrand Rise
# Aqua Rise => Aqua Rise
# Spring Rise => Spring Rise
# Lestwick Rise => Lestwick Rise
# Cathedral Rise => Cathedral Rise
# Sherwood Rise => Sherwood Rise
# Niland Rise => Niland Rise
# Sanctuary Rise => Sanctuary Rise
# Tintern Rise => Tintern Rise
# The Rise => The Rise
# Tuscany Rise => Tuscany Rise
# Fasan Rise => Fasan Rise
# Rowena Rise => Rowena Rise
# Greenhill Rise => Greenhill Rise
# Heathfield Rise => Heathfield Rise
# Sunny Rise => Sunny Rise
# Felicia Rise => Felicia Rise
# Stanlake Rise => Stanlake Rise
# Outlook Rise => Outlook Rise
# Richardson Rise => Richardson Rise
# Scenic Rise => Scenic Rise
# Rosella Rise => Rosella Rise
# Talisman Rise => Talisman Rise
# Toogoods Rise => Toogoods Rise
# Chantelle Rise => Chantelle Rise
# Oaktree Rise => Oaktree Rise
# Professor's Walk => Professor's Walk
# Rainforest Walk => Rainforest Walk
# Eagleview Walk => Eagleview Walk
# Innovation Walk => Innovation Walk
# Batman Walk => Batman Walk
# Sports Walk => Sports Walk
# Railway Walk => Railway Walk
# Mulberry Walk => Mulberry Walk
# Waterview Walk => Waterview Walk
# Illowra Walk => Illowra Walk
# Abbey Walk => Abbey Walk
# Maculata Walk => Maculata Walk
# Cherry Walk => Cherry Walk
# Flinders Walk => Flinders Walk
# Kara Walk => Kara Walk
# Berrywood Walk => Berrywood Walk
# Dukes Walk => Dukes Walk
# Saligna Walk => Saligna Walk
# Solstice Walk => Solstice Walk
# Chancellor's Walk => Chancellor's Walk
# Jacobus Walk => Jacobus Walk
# Rebecca Walk => Rebecca Walk
# Forest Walk => Forest Walk
# Woodcock Walk => Woodcock Walk
# Knoll Walk => Knoll Walk
# Lightwood Walk => Lightwood Walk
# College Walk => College Walk
# Kingsway => Kingsway
# The Quadrangle => The Quadrangle
# Little Bourke => Little Bourke
# Bourke => Bourke
# cnr Arden & Dryburgh Streets => cnr Arden & Dryburgh Streets
# Bourke and Swanston Streets => Bourke and Swanston Streets
# Corner Grey and Simpson Streets => Corner Grey and Simpson Streets
# Anley Mews => Anley Mews
# Fisher Mews => Fisher Mews
# Montvale Mews => Montvale Mews
# Eucalyptus Mews => Eucalyptus Mews
# Steorra Mews => Steorra Mews
# McAllister Mews => McAllister Mews
# The Mews => The Mews
# Gregory Mews => Gregory Mews
# Natalie Mews => Natalie Mews
# Selo Mews => Selo Mews
# Abbey Mews => Abbey Mews
# Punari Mews => Punari Mews
# The Strand => The Strand
# Malvern => Malvern
# The Mall => The Mall
# Bourke Street Mall => Bourke Street Mall
# Dennison Mall => Dennison Mall
# Eaton Mall => Eaton Mall
# Brittania Mall => Brittania Mall
# Nicholson Street Mall => Nicholson Street Mall
# Station Stf => Station Stf
# Belmont Avenue North => Belmont Avenue North
# Brunswick Street North => Brunswick Street North
# North => North
# Bannons Lane North => Bannons Lane North
# Lincoln Square North => Lincoln Square North
# Yarra Road, Croydon North => Yarra Road, Croydon North
# Railway Parade North => Railway Parade North
# Harley Street North => Harley Street North
# Laurel Grove North => Laurel Grove North
# Centreway => Centreway
# The Centreway => The Centreway
# Barmah Drive West => Barmah Drive West
# Manningham Road West => Manningham Road West
# Metrolink Circuit West => Metrolink Circuit West
# Surrey Road West => Surrey Road West
# Palmerston Road West => Palmerston Road West
# Craigieburn Road West => Craigieburn Road West
# Toorak Road West => Toorak Road West
# Como Parade West => Como Parade West
# Nell Street West => Nell Street West
# Kirkham Road West => Kirkham Road West
# Belmont Road West => Belmont Road West
# Main Road West => Main Road West
# Bond Street West => Bond Street West
# Grant Crescent West => Grant Crescent West
# George => George
# East Concourse => East Concourse
# Merri Concourse => Merri Concourse
# North Concourse => North Concourse
# Railway Place East => Railway Place East
# Grant Street East => Grant Street East
# Main Road East => Main Road East
# Belmont Road East => Belmont Road East
# Bayfield Road East => Bayfield Road East
# Bungalook Road East => Bungalook Road East
# Como Parade East => Como Parade East
# Argyle Place East => Argyle Place East
# Foster Street East => Foster Street East
# Barmah Drive East => Barmah Drive East
# Blackburn Road East => Blackburn Road East
# Siddeley => Siddeley
# Tin Alley => Tin Alley
# Croft Alley => Croft Alley
# Globe Alley => Globe Alley
# P => P
# The Sands => The Sands
# The Boardwalk => The Boardwalk
# The Outlook => The Outlook
# Larkspur Circuit => Larkspur Circuit
# Richmond Circuit => Richmond Circuit
# Napoli Circuit => Napoli Circuit
# Simmington Circuit => Simmington Circuit
# Parkside Circuit => Parkside Circuit
# The Circuit => The Circuit
# Glastonbury Circuit => Glastonbury Circuit
# Ashbrook Circuit => Ashbrook Circuit
# Sun Orchid Circuit => Sun Orchid Circuit
# Lansdowne Circuit => Lansdowne Circuit
# Macquarie Circuit => Macquarie Circuit
# Metrolink Circuit => Metrolink Circuit
# Livingstone Circuit => Livingstone Circuit
# De Havilland Circuit => De Havilland Circuit
# West Circuit => West Circuit
# Stadium Circuit => Stadium Circuit
# Hutchins Circuit => Hutchins Circuit
# Queensberry Circuit => Queensberry Circuit
# Excelsior Circuit => Excelsior Circuit
# Tullimbar Circuit => Tullimbar Circuit
# Sandon Circuit => Sandon Circuit
# Stables Circuit => Stables Circuit
# Compark Circuit => Compark Circuit
# Technology Circuit => Technology Circuit
# Aspendale Presbyterian Church => Aspendale Presbyterian Church
# Victoria => Victoria
# Brighton => Brighton
# Preston Chambers Arcade => Preston Chambers Arcade
# Campbell Arcade => Campbell Arcade
# Kings Arcade => Kings Arcade
# Tom Roberts => Tom Roberts
# Carr => Carr
# Lt Lonsdale => Lt Lonsdale
# Primrose Street (cnr Albion Street) => Primrose Street (cnr Albion Street)
# Langhorne => Langhorne
# Heatherton => Heatherton
# Langridge => Langridge
# The Concord => The Concord
# Yates Wynd => Yates Wynd
# Buvelot Wynd => Buvelot Wynd
# Illawara => Illawara
# Aston Heath => Aston Heath
# The Heath => The Heath
# The Promenade => The Promenade
# Troups Creek Promenade => Troups Creek Promenade
# Southbank Promenade => Southbank Promenade
# Newquay Promenade => Newquay Promenade
# South Wharf Promenade => South Wharf Promenade
# Saltwater Promenade => Saltwater Promenade
# Victoria Harbour Promenade => Victoria Harbour Promenade
# Broadway => Broadway
# Cascades View => Cascades View
# Sky View => Sky View
# Kaleno View => Kaleno View
# Second Hand Station => Second Hand Station
# Station Station => Station Station
# Carlisle => Carlisle
# The Ridge => The Ridge
# Monarch Ridge => Monarch Ridge
# Killarney Ridge => Killarney Ridge
# The Elms => The Elms
# The Glade => The Glade
# Bushview Glade => Bushview Glade
# Rathmullen Quadrant => Rathmullen Quadrant
# Dawsons Glen => Dawsons Glen
# Keswick Glen => Keswick Glen
# West Finger Pier => West Finger Pier
# Station Pier => Station Pier
# The Deviation => The Deviation
# Falcon Crest => Falcon Crest
# The Crest => The Crest
# Tivoli Gardens => Tivoli Gardens
# Georgian Gardens => Georgian Gardens
# Kingfisher Gardens => Kingfisher Gardens
# Harrow Gardens => Harrow Gardens
# Covent Gardens => Covent Gardens
# Wembley Gardens => Wembley Gardens
# Wroxham Gardens => Wroxham Gardens
# Forrest Hill => Forrest Hill
# Artists Hill => Artists Hill
# Graduate Road, University Hill => Graduate Road, University Hill
# Murray Roađ => Murray Roađ
# Avalon Roađ => Avalon Roađ
# The Grange => The Grange
# Morton => Morton
# Suite 1, St Vincent’s Private Hospital, 5 Studley Ave => Suite 1, St Vincent’s Private Hospital, 5 Studley Ave
# Victoria Ave => Victoria Ave
# The Woodland => The Woodland
# The Fairway => The Fairway
# Marden => Marden
# Amery Street. => Amery Street.
# Orrong => Orrong
# Balwyn => Balwyn
# Elizabeth => Elizabeth
# Camberwell Roah => Camberwell Roah
# Springfield => Springfield
# Toorak => Toorak
# Elder => Elder
# The Knoll => The Knoll
# Rouse => Rouse
# Eileen => Eileen
# Nelson => Nelson
# black street => black street
# Grantham street => Grantham street
# Moubray street => Moubray street
# Church street => Church street
# collins street => collins street
# Kavanagh street => Kavanagh street
# walter street => walter street
# Lower Dandenong Round => Lower Dandenong Round
# Woody Link => Woody Link
# The Nook => The Nook
# Strome Cres => Strome Cres
# London Dr. => London Drive
# Newlands Rof => Newlands Rof
# Dunhelen Rof => Dunhelen Rof
# Whitehorse Roy => Whitehorse Roy
# London Dr, => London Drive
# Indian Dr, => Indian Drive
# The Crossway => The Crossway
# Reserve Rd => Reserve Road
# Warrigal Rd => Warrigal Road
# Cotham Rd => Cotham Road
# Riversdale Rd => Riversdale Road
# Sydney Rd => Sydney Road
# Cochranes Rd => Cochranes Road
# Bayswater Rd => Bayswater Road
# Roberts Rd => Roberts Road
# Doncaster Rd => Doncaster Road
# Greens Rd => Greens Road
# Burke Rd => Burke Road
# McCarthy Gr => McCarthy Gr
# Georgette => Georgette
# Hazelview Pocket => Hazelview Pocket
# Scoresby Ro => Scoresby Road
# Centre Want => Centre Want
# The Causeway => The Causeway
# Dandenong - Frankston Rog => Dandenong - Frankston Rog
# Buckhurst Stc => Buckhurst Stc
# Lacey Stg => Lacey Stg
# Dandenong - Frankston Road d => Dandenong - Frankston Road d
# The Eyrie => The Eyrie
# Bayside Avp => Bayside Avp
# Separation St. => Separation Street
# The Summit => The Summit
# Loughies Track => Loughies Track
# The Croft => The Croft
# Edward.Street => Edward.Street
# Maygar => Maygar
# high Street, Armadale VIC => high Street, Armadale VIC
# The Righi => The Righi
# Nerreman Gateway => Nerreman Gateway
# The Gateway => The Gateway
# Chevy Chase => Chevy Chase
# Coolabindi Chase => Coolabindi Chase
# Tho => Tho
# Cardigan Street, Melbourne => Cardigan Street, Melbourne
# Cnr City Road & Cecil Street South Melbourne => Cnr City Road & Cecil Street South Melbourne
# Franklyn => Franklyn
# La Trobe => La Trobe
# Bourke Street Footbridge => Bourke Street Footbridge
# Miller Street call => Miller Street call
# Quay Blvd => Quay Blvd
# Bond St W => Bond St W
# Hyde Park => Hyde Park
# Friar Park => Friar Park
# Batman Park => Batman Park
# Turner => Turner
# Star Circus => Star Circus
# Dalbeattie => Dalbeattie
# Guildford Lane. => Guildford Lane.
# Dublin Green => Dublin Green
# Allister => Allister
# De Havilland => De Havilland
# The Vaucluse => The Vaucluse
# Ferrars => Ferrars
# PARK STREET => PARK STREET
# 251 => 251
# Kidderminster => Kidderminster
# Stawell => Stawell
# Melbourne Central Shopping Centre Shop 146 Knox Lane, 211 La Trobe Street Melbourne, 3000 (Enter from Swanston or from inside the Centre) => Melbourne Central Shopping Centre Shop 146 Knox Lane, 211 La Trobe Street Melbourne, 3000 (Enter from Swanston or from inside the Centre)
# Alchester Cresent => Alchester Cresent
# Glenhuntly => Glenhuntly
# 253 Para Road, Greensborough => 253 Para Road, Greensborough
# Oxford => Oxford
# Logis Bouf => Logis Bouf
# Burwood Highway, East Burwood Reserve => Burwood Highway, East Burwood Reserve
# Arrival Drive Melbourne Airport => Arrival Drive Melbourne Airport
# 2B Stott St Preston => 2B Stott St Preston
# Maroondah Higway => Maroondah Higway
# Community Hub => Community Hub
# Princes Higl => Princes Higl
# Swallow => Swallow
# Corner Plenty & Greenhills Roads => Corner Plenty & Greenhills Roads
# Sydney and Brunswick Roads => Sydney and Brunswick Roads
# Murrayd rd => Murrayd Road
# Racecourse Road Offramp => Racecourse Road Offramp
# Dynon Road1 => Dynon Road1
# Thomas House => Thomas House
# driveway => driveway
# The Corso => The Corso
# Glenara Ford => Glenara Ford
# The Briars => The Briars
# The Robbins => The Robbins
# tha => tha
# The Old Stock Run => The Old Stock Run

# %% [markdown]
# ### Auditing the  Zipcode

# %%
osmfile = "Melbourne.osm"
zip_type_re = re.compile(r'\d{4}$')

def audit_ziptype(zip_types, zipcode):
    if zipcode[0:1] != 3:
        zip_types[zipcode[0:1]].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    zip_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_ziptype(zip_types,tag.attrib['v'])
    osm_file.close()
    return zip_types

zip_print = audit_zip(osmfile)

def test():    
    pprint.pprint(dict(zip_print))

if __name__ == '__main__':
    test()
# Out:
# {'2': {'2004', '2181'},
#  '3': {'3000',
#        '3001',
#        '3002',
#        '3003',
#        '3004',
#        '3005',
#        '3006',
#        '3006;3130',
#        '3008',
#        '3010',
#        '3011',
#        '3012',
#        '3013',
#        '3013s',
#        '3015',
#        '3016',
#        '3018',
#        '3019',
#        '3020',
#        '3021',
#        '3022',
#        '3023',
#        '3025',
#        '3026',
#        '3027',
#        '3028',
#        '3029',
#        '3030',
#        '3031',
#        '3031-',
#        '3032',
#        '3033',
#        '3034',
#        '3036',
#        '3037',
#        '3038',
#        '3039',
#        '3040',
#        '3040\u200e',
#        '3041',
#        '3042',
#        '3043',
#        '3044',
#        '3045',
#        '3046',
#        '3047',
#        '3048',
#        '3049',
#        '3050',
#        '3051',
#        '3052',
#        '3053',
#        '3054',
#        '3055',
#        '3056',
#        '3057',
#        '3058',
#        '3059',
#        '3060',
#        '3061',
#        '3062',
#        '3063',
#        '3064',
#        '3065',
#        '3066',
#        '3067',
#        '3068',
#        '3070',
#        '3071',
#        '3072',
#        '3073',
#        '3074',
#        '3075',
#        '3076',
#        '3078',
#        '3079',
#        '3081',
#        '3082',
#        '3083',
#        '3084',
#        '3085',
#        '3086',
#        '3087',
#        '3088',
#        '3089',
#        '3090',
#        '3091',
#        '3093',
#        '3094',
#        '3095',
#        '3096',
#        '3097',
#        '3099',
#        '3101',
#        '3102',
#        '3103',
#        '3104',
#        '3105',
#        '3106',
#        '3107',
#        '3108',
#        '3109',
#        '3111',
#        '3113',
#        '3114',
#        '3115',
#        '3121',
#        '3122',
#        '3123',
#        '3124',
#        '3125',
#        '3126',
#        '3127',
#        '3128',
#        '3129',
#        '3130',
#        '3131',
#        '3132',
#        '3133',
#        '3134',
#        '3135',
#        '3136',
#        '3141',
#        '3142',
#        '3143',
#        '3144',
#        '3145',
#        '3146',
#        '3147',
#        '3148',
#        '3149',
#        '3150',
#        '3151',
#        '3152',
#        '3153',
#        '3155',
#        '3156',
#        '3161',
#        '3162',
#        '3163',
#        '3165',
#        '3166',
#        '3167',
#        '3168',
#        '3169',
#        '3170',
#        '3171',
#        '3172',
#        '3173',
#        '3174',
#        '3175',
#        '3177',
#        '3178',
#        '3179',
#        '3180',
#        '3181',
#        '3182',
#        '3183',
#        '3184',
#        '3185',
#        '3186',
#        '3187',
#        '3188',
#        '3189',
#        '3190',
#        '3191',
#        '3192',
#        '3193',
#        '3194',
#        '3195',
#        '3196',
#        '3197',
#        '3198',
#        '3202',
#        '3204',
#        '3205',
#        '3206',
#        '3206Unset',
#        '3207',
#        '3280',
#        '3335',
#        '3427',
#        '3428',
#        '3429',
#        '3503',
#        '3750',
#        '3752',
#        '3754',
#        '3755',
#        '3759',
#        '3760',
#        '3761',
#        '380',
#        '3800',
#        '3802',
#        '3803',
#        '3804',
#        '3805',
#        '3817',
#        '385'},
#  '4': {'4156'},
#  '8': {'805'},
#  'C': {'Centre Dandenong Road'},
#  'N': {'N'},
#  'V': {'Victoria', 'VIC 3000', 'VIC 3166'},
#  's': {'s'}}

# %% [markdown]
# ### Correcting the zipcodes

# %%
'''
This code will update non 4-digit zipcode.
    - If 8 digit as 8 digits 3006;3130, only the first 4 digits are kept.
    - If 4 digit and ends alphabets such as 3206Unset, only the 4 digits are kept.
    - If 4 number and starts alphabets and space such as VIC 3000, only the 4 digits are kept.
'''
def update_zipcode(zipcode):
    """Clean postcode to a uniform format of 4 digit; Return updated postcode"""
    if re.findall(r'^\d{4}$', zipcode): # 4 digits 3000
        valid_zipcode = zipcode
        return valid_zipcode
    elif re.findall(r'(^\d{4});\d{4}$', zipcode): # 8 digits 3006;3130
        valid_zipcode = re.findall(r'(^\d{4});\d{4}$', zipcode)[0]
        return valid_zipcode  
    elif re.findall(r'(^\d{4})\D*', zipcode): # four number with alphabets such as 3206Unset
        valid_zipcode = re.findall(r'\d{4}', zipcode)[0]
        return valid_zipcode
    elif re.findall(r'(^\D*)s*\d{4}', zipcode): # four number with alphabets and space such as VIC 3000
        valid_zipcode = re.findall(r'\d{4}', zipcode)[0]
        return valid_zipcode   
    else: #return default zipcode to avoid overwriting
        return zipcode   

def test_zip():
    for zips, ways in zip_print.items():
        for name in ways:
            better_name = update_zipcode(name)
            print (name, "=>", better_name)

if __name__ == '__main__':
    test_zip()
# Out:
# 3191 => 3191
# 3163 => 3163
# 3133 => 3133
# 3177 => 3177
# 3101 => 3101
# 3022 => 3022
# 3122 => 3122
# 3429 => 3429
# 3099 => 3099
# 3006 => 3006
# 3804 => 3804
# 3805 => 3805
# 3047 => 3047
# 3103 => 3103
# 3136 => 3136
# 3038 => 3038
# 3013 => 3013
# 3107 => 3107
# 3006;3130 => 3006
# 3028 => 3028
# 3088 => 3088
# 3044 => 3044
# 3143 => 3143
# 3197 => 3197
# 3055 => 3055
# 3048 => 3048
# 3206 => 3206
# 3106 => 3106
# 3025 => 3025
# 3202 => 3202
# 3108 => 3108
# 3104 => 3104
# 3040 => 3040
# 3036 => 3036
# 3167 => 3167
# 3023 => 3023
# 3817 => 3817
# 3206Unset => 3206
# 3148 => 3148
# 3008 => 3008
# 3076 => 3076
# 3045 => 3045
# 3053 => 3053
# 3204 => 3204
# 3043 => 3043
# 3020 => 3020
# 3186 => 3186
# 3015 => 3015
# 3427 => 3427
# 3051 => 3051
# 3074 => 3074
# 3124 => 3124
# 3802 => 3802
# 3114 => 3114
# 3050 => 3050
# 3054 => 3054
# 3198 => 3198
# 3183 => 3183
# 3752 => 3752
# 3010 => 3010
# 3132 => 3132
# 3149 => 3149
# 3195 => 3195
# 3097 => 3097
# 3123 => 3123
# 3093 => 3093
# 3113 => 3113
# 3152 => 3152
# 3168 => 3168
# 3073 => 3073
# 3063 => 3063
# 3042 => 3042
# 3078 => 3078
# 3058 => 3058
# 3162 => 3162
# 3128 => 3128
# 3750 => 3750
# 3190 => 3190
# 3029 => 3029
# 3102 => 3102
# 3174 => 3174
# 3084 => 3084
# 3172 => 3172
# 3062 => 3062
# 3001 => 3001
# 3171 => 3171
# 3129 => 3129
# 3095 => 3095
# 3166 => 3166
# 3032 => 3032
# 3503 => 3503
# 3070 => 3070
# 3072 => 3072
# 3005 => 3005
# 3089 => 3089
# 3039 => 3039
# 3761 => 3761
# 3156 => 3156
# 3187 => 3187
# 3027 => 3027
# 3182 => 3182
# 3130 => 3130
# 3066 => 3066
# 3002 => 3002
# 3135 => 3135
# 3800 => 3800
# 3121 => 3121
# 3087 => 3087
# 3019 => 3019
# 3049 => 3049
# 3090 => 3090
# 3086 => 3086
# 3031 => 3031
# 3037 => 3037
# 3030 => 3030
# 3207 => 3207
# 3046 => 3046
# 3181 => 3181
# 3759 => 3759
# 3173 => 3173
# 3131 => 3131
# 3165 => 3165
# 3079 => 3079
# 3041 => 3041
# 3184 => 3184
# 3091 => 3091
# 3075 => 3075
# 3193 => 3193
# 3004 => 3004
# 3068 => 3068
# 3175 => 3175
# 3185 => 3185
# 3000 => 3000
# 3188 => 3188
# 3034 => 3034
# 3760 => 3760
# 3094 => 3094
# 3021 => 3021
# 3335 => 3335
# 385 => 385
# 3059 => 3059
# 3141 => 3141
# 3085 => 3085
# 3142 => 3142
# 3146 => 3146
# 3755 => 3755
# 3150 => 3150
# 3155 => 3155
# 3026 => 3026
# 3057 => 3057
# 3192 => 3192
# 3064 => 3064
# 3012 => 3012
# 3179 => 3179
# 3071 => 3071
# 3096 => 3096
# 3065 => 3065
# 380 => 380
# 3754 => 3754
# 3196 => 3196
# 3803 => 3803
# 3145 => 3145
# 3161 => 3161
# 3056 => 3056
# 3115 => 3115
# 3180 => 3180
# 3428 => 3428
# 3125 => 3125
# 3016 => 3016
# 3067 => 3067
# 3205 => 3205
# 3109 => 3109
# 3169 => 3169
# 3082 => 3082
# 3105 => 3105
# 3126 => 3126
# 3189 => 3189
# 3081 => 3081
# 3033 => 3033
# 3178 => 3178
# 3280 => 3280
# 3127 => 3127
# 3144 => 3144
# 3153 => 3153
# 3083 => 3083
# 3134 => 3134
# 3031- => 3031
# 3018 => 3018
# 3170 => 3170
# 3147 => 3147
# 3151 => 3151
# 3194 => 3194
# 3060 => 3060
# 3040‎ => 3040
# 3003 => 3003
# 3111 => 3111
# 3061 => 3061
# 3013s => 3013
# 3052 => 3052
# 3011 => 3011
# Centre Dandenong Road => Centre Dandenong Road
# Victoria => Victoria
# VIC 3000 => 3000
# VIC 3166 => 3166
# 805 => 805
# 2004 => 2004
# 2181 => 2181
# N => N
# 4156 => 4156
# s => s

# %% [markdown]
# ### Convert Database into .csv

# %%
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

OSM_PATH = "Melbourne.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']  
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  
    #YOUR CODE HERE
    if element.tag == 'node':
        for attrib in element.attrib:
            if attrib in NODE_FIELDS:
                node_attribs[attrib] = element.attrib[attrib]
        
        for child in element:
            node_tag = {}
            if LOWER_COLON.match(child.attrib['k']):
                node_tag['type'] = child.attrib['k'].split(':',1)[0]
                node_tag['key'] = child.attrib['k'].split(':',1)[1]
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                tags.append(node_tag)
            elif PROBLEMCHARS.match(child.attrib['k']):
                continue
            else:
                node_tag['type'] = 'regular'
                node_tag['key'] = child.attrib['k']
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                tags.append(node_tag)
        
        return {'node': node_attribs, 'node_tags': tags}
        
    elif element.tag == 'way':
        for attrib in element.attrib:
            if attrib in WAY_FIELDS:
                way_attribs[attrib] = element.attrib[attrib]
        
        position = 0
        for child in element:
            way_tag = {}
            way_node = {}
            
            if child.tag == 'tag':
                if LOWER_COLON.match(child.attrib['k']):
                    way_tag['type'] = child.attrib['k'].split(':',1)[0]
                    way_tag['key'] = child.attrib['k'].split(':',1)[1]
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                elif PROBLEMCHARS.match(child.attrib['k']):
                    continue
                else:
                    way_tag['type'] = 'regular'
                    way_tag['key'] = child.attrib['k']
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                    
            elif child.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child.attrib['ref']
                way_node['position'] = position
                position += 1
                way_nodes.append(way_node)
        
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}




# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.items())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.decode('utf-8') if isinstance(v,bytes) else v) for k, v in row.items()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=False)

# %% [markdown]
# ## Create asqlite db and store populates with CSVs##

# %%
# Creating the database and tables
import sqlite3
import csv

conn = sqlite3.connect('data_wrangling.sqlite')

conn.text_factory = str
cur = conn.cursor()

#Make some fresh tables using executescript()
cur.execute('''DROP TABLE IF EXISTS nodes''')
cur.execute('''DROP TABLE IF EXISTS nodes_tags''')
cur.execute('''DROP TABLE IF EXISTS ways''')
cur.execute('''DROP TABLE IF EXISTS ways_tags''')
cur.execute('''DROP TABLE IF EXISTS ways_nodes''')


cur.execute('''CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT)
''')

with open('nodes.csv','r') as nodes_table: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(nodes_table) # comma is default delimiter
    to_db = [(i['id'], i['lat'], i['lon'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]

cur.executemany("INSERT INTO nodes VALUES (?, ?, ?, ?, ?, ?, ?, ?);", to_db)

#
cur.execute('''CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id))
''')

with open('nodes_tags.csv','r') as nodes_tags_table: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(nodes_tags_table) # comma is default delimiter
    to_db = [(i['id'], i['key'], i['value'], i['type']) for i in dr]

cur.executemany("INSERT INTO nodes_tags VALUES (?, ?, ?, ?);", to_db)

#
cur.execute('''CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT)
''')

with open('ways.csv','r') as ways_table: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(ways_table) # comma is default delimiter
    to_db = [(i['id'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]

cur.executemany("INSERT INTO ways VALUES (?, ?, ?, ?, ?, ?);", to_db)  

#
cur.execute('''CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id))
''')

with open('ways_tags.csv','r') as ways_tags_table: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(ways_tags_table) # comma is default delimiter
    to_db = [(i['id'], i['key'], i['value'], i['type']) for i in dr]

cur.executemany("INSERT INTO ways_tags VALUES (?, ?, ?, ?);", to_db)

#
cur.execute('''CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id))
''')

with open('ways_nodes.csv','r') as ways_nodes_table: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(ways_nodes_table) # comma is default delimiter
    to_db = [(i['id'], i['node_id'], i['position']) for i in dr]

cur.executemany("INSERT INTO ways_nodes VALUES (?, ?, ?);", to_db)

#Save changes
conn.commit()

# %% [markdown]
# ## Files sizes

# %%
import os

print ('The Melbourne.osm file is {} MB'.format(os.path.getsize('Melbourne.osm')/1.0e2))
print ('The nodes.csv file is {} MB'.format(os.path.getsize('nodes.csv')/1.0e2))
print ('The nodes_tags.csv file is {} MB'.format(os.path.getsize('nodes_tags.csv')/1.0e2))
print ('The ways.csv file is {} MB'.format(os.path.getsize('ways.csv')/1.0e2))
print ('The ways_nodes.csv file is {} MB'.format(os.path.getsize('ways_nodes.csv')/1.0e2))
print ('The ways_tags.csv file is {} MB'.format(os.path.getsize('ways_tags.csv')/1.0e2))
print ('The data_wrangling.sqlite file is {} MB'.format(os.path.getsize('data_wrangling.sqlite')/1.0e2))
# Out:
# The Melbourne.osm file is 3406934.84 MB
# The nodes.csv file is 953806.71 MB
# The nodes_tags.csv file is 409174.61 MB
# The ways.csv file is 59557.36 MB
# The ways_nodes.csv file is 641591.82 MB
# The ways_tags.csv file is 401646.6 MB
# The data_wrangling.sqlite file is 2225152.0 MB

# %% [markdown]
# ## Data Overviews

# %% [markdown]
# The queries below provides an overview of the Melbourne, AUS OpenStreetMap dataset.

# %% [markdown]
# #### The Number of nodes

# %%
nodes_count = conn.cursor()
nodes_count.execute("SELECT COUNT(*) FROM nodes")

nodes_count = nodes_count.fetchall()
 
for row in nodes_count:
    print(row)
# Out:
# (2301716,)

# %% [markdown]
# #### The Number of ways

# %%
ways_count = conn.cursor()
ways_count.execute("SELECT COUNT(*) FROM ways")

ways_count = ways_count.fetchall()
 
for row in ways_count:
    print(row)
# Out:
# (356310,)

# %% [markdown]
# #### The top amenities

# %%
top_amenities = conn.cursor()
t = ('amenity',)
top_amenities.execute("SELECT value, COUNT(*) as num FROM nodes_tags WHERE key=? GROUP BY value ORDER BY num DESC LIMIT 10", t)

top_amenities = top_amenities.fetchall()
 
for row in top_amenities:
    print(row)
# Out:
# ('bench', 2577)
# ('restaurant', 2076)
# ('cafe', 1726)
# ('waste_basket', 1469)
# ('bicycle_parking', 1427)
# ('fast_food', 1140)
# ('post_box', 1012)
# ('drinking_water', 960)
# ('toilets', 718)
# ('telephone', 647)

# %% [markdown]
# #### The Places of Worship in the area (extra idea)

# %%
warship_area = conn.cursor()

query='''select count(value) from nodes_tags where key = 'amenity' AND value LIKE '%worship%'; '''

result=cur.execute(query)
for row in result:
    print (row)
# Out:
# (377,)

# %% [markdown]
# #### The umber of Schoolsextra idea)

# %%
query='''select count(value) from nodes_tags where key = 'amenity' AND value LIKE '%School%'; '''

result=cur.execute(query)
for row in result:
    print (row)
# Out:
# (78,)

# %% [markdown]
# #### The top sports

# %%
top_sports = conn.cursor()
t = ('sport',)
top_sports.execute("SELECT value, COUNT(*) as num FROM nodes_tags WHERE key=? GROUP BY value ORDER BY num DESC LIMIT 10", t)

top_sports = top_sports.fetchall()
 
for row in top_sports:
    print(row)
# Out:
# ('basketball', 30)
# ('fitness', 23)
# ('swimming', 19)
# ('cricket_nets', 12)
# ('skateboard', 12)
# ('australian_football', 8)
# ('tennis', 8)
# ('soccer', 7)
# ('yoga', 7)
# ('cricket', 6)

# %% [markdown]
# #### The top tourism

# %%
top_tourism = conn.cursor()
t = ('tourism', 'tourism_1')
top_tourism.execute("SELECT value, COUNT(*) as num FROM nodes_tags WHERE key=? GROUP BY value UNION SELECT value, COUNT(*) as num FROM nodes_tags WHERE key=? GROUP BY value ORDER BY num DESC", t)

top_tourism = top_tourism.fetchall()
 
for row in top_tourism:
    print(row)
# Out:
# ('information', 225)
# ('picnic_site', 220)
# ('artwork', 213)
# ('hotel', 122)
# ('viewpoint', 103)
# ('attraction', 65)
# ('hostel', 32)
# ('museum', 29)
# ('motel', 28)
# ('gallery', 26)
# ('guest_house', 18)
# ('apartment', 5)
# ('caravan_site', 3)
# ('aquarium', 2)
# ('camp_site', 2)
# ('attraction', 1)
# ('bed_and_breakfast', 1)
# ('lookout', 1)
# ('theme_park', 1)

# %% [markdown]
# #### The top citys

# %%
top_city = conn.cursor()
t = ('city',)
top_city.execute("SELECT value, COUNT(*) as num FROM nodes_tags WHERE key=? GROUP BY value ORDER BY num DESC LIMIT 10", t)

top_city = top_city.fetchall()
 
for row in top_city:
    print(row)
# Out:
# ('Glen Waverley', 13307)
# ('Wantirna South', 7270)
# ('Wheelers Hill', 6797)
# ('Mount Waverley', 4226)
# ('Montmorency', 3773)
# ('Melbourne', 2802)
# ('Wantirna', 2746)
# ('Mulgrave', 1901)
# ('Vermont South', 1677)
# ('Greensborough', 1646)

# %% [markdown]
# #### The top way of payments

# %%
top_payment = conn.cursor()
t = ('payment',)
top_payment.execute("SELECT key, COUNT(*) as num FROM nodes_tags WHERE type=? GROUP BY key ORDER BY num DESC", t)

top_payment = top_payment.fetchall()
 
for row in top_payment:
    print(row)
# Out:
# ('coins', 98)
# ('mastercard', 87)
# ('visa', 87)
# ('credit_cards', 55)
# ('cash', 49)
# ('telephone_cards', 47)
# ('bitcoin', 43)
# ('notes', 39)
# ('debit_cards', 37)
# ('american_express', 22)
# ('contactless', 12)
# ('maestro', 8)
# ('cards', 3)
# ('laser', 3)
# ('visa_debit', 3)
# ('litecoin', 2)
# ('card', 1)
# ('darkcoin', 1)
# ('direct_deposit', 1)
# ('money_order', 1)
# ('paypal', 1)
# ('vertcoin', 1)
# ('visa_electron', 1)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The OpenStreetMap data is a great place for users to contribute to the data. However, if the integrity and completenenss of data are not maintained, it can't compete with other map services such as Google Maps or Apple Maps which has a better user experience and more structure ways of searching for info.
#
# With more care taken, OpenStreetMap is capable of being the Wikipedia of maps

# %% [markdown]
# ## Suggestion

# %% [markdown]
# A data validation rules may be helpufl when the data is being entered. The validation could contribute in inproving and  keeping the data consistent by minimizing errors.
# Below query shows all ameneties and how we can bucket some of the sub categories into one:

# %%
query='''select DISTINCT value from nodes_tags where key = 'amenity' and value like '%_%'; '''

result=cur.execute(query)
for row in result:
    print (row)
# Out:
# ('hospital',)
# ('place_of_worship',)
# ('parking_space',)
# ('toilets',)
# ('police',)
# ('pub',)
# ('fuel',)
# ('cafe',)
# ('parking',)
# ('cinema',)
# ('public_building',)
# ('post_box',)
# ('restaurant',)
# ('school',)
# ('shelter',)
# ('courthouse',)
# ('bus_station',)
# ('parking_entrance',)
# ('fast_food',)
# ('telephone',)
# ('boat_rental',)
# ('theatre',)
# ('bank',)
# ('library',)
# ('post_office',)
# ('fire_station',)
# ('drinking_water',)
# ('bbq',)
# ('pharmacy',)
# ('nightclub',)
# ('kindergarten',)
# ('doctors',)
# ('community_centre',)
# ('atm',)
# ('bench',)
# ('childcare',)
# ('rsl',)
# ('car_wash',)
# ('bicycle_parking',)
# ('fountain',)
# ('weighbridge',)
# ('taxi',)
# ('bar',)
# ('car_rental',)
# ('ferry_terminal',)
# ('recycling',)
# ('community_hall',)
# ('veterinary',)
# ('exercise',)
# ('clinic',)
# ('jetty',)
# ('waste_basket',)
# ('college',)
# ('dentist',)
# ('brothel',)
# ('ice_cream',)
# ('university',)
# ('money_transfer',)
# ('bureau_de_change',)
# ('arts_centre',)
# ('embassy',)
# ('internet_cafe',)
# ('restaurant; cafe',)
# ('stripclub',)
# ('marketplace',)
# ('bicycle_rental',)
# ('waste_transfer_station',)
# ('vending_machine',)
# ('clock',)
# ('car_sharing',)
# ('wifi',)
# ('gambling',)
# ('townhall',)
# ('hunting_stand',)
# ('gym',)
# ('sports',)
# ('swimming_pool',)
# ('trash_can',)
# ('parking_meter',)
# ('compressed_air',)
# ('convenience',)
# ('studio',)
# ('art_school',)
# ('PO boxes',)
# ('philatelic',)
# ('pathology',)
# ('toy_library',)
# ('support service',)
# ('bus hire',)
# ('engineer',)
# ('food_court',)
# ('car_service',)
# ('skatepark',)
# ('nursing_home',)
# ('motorcycle_parking',)
# ('social_facility',)
# ('shower',)
# ('casino',)
# ('survey',)
# ('karaoke_box',)
# ('waste_disposal',)
# ('According to the website, this is a "gay sauna". Seems more like amenity=nightclub than amenity=sauna maybe?',)
# ('picnic_table',)
# ('bandstand',)
# ('bicycle_repair_station',)
# ('spa',)
# ('driving_school',)
# ('club',)
# ('dojo',)
# ('audiologist',)
# ('beauty',)
# ('charging_station',)
# ('printer',)
# ('coworking_space',)
# ('vehicle_inspection',)
# ('crematorium',)
# ('animal_boarding',)
# ('music_school',)
# ('smoking_area',)
# ('sanitary_dump_station',)
# ('watering_place',)
# ('meeting_point',)
# ('events_venue',)
# ('gate',)
# ('animal_shelter',)
# ('public_bookcase',)
# ('water_point',)
# ('prep_school',)
# ('juice_bar',)
# ('loading_dock',)

# %% [markdown]
# For in stance, for the name of amenities, there are some obiviously errors in nanes such as:
#     - loading_dock
#     - driving_school
# The "_" should've be allowed into the names of amenities.
